# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\tirumaleswarasai.t\\Desktop\\pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
rows,coloumns = df.shape
rows
coloumns
# Out:
# 12

# %%
df[50:71]
# Out:
#      #       Name    Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50  45  Vileplume     Grass    Poison  75      80       85      110       90
# 51  46      Paras       Bug     Grass  35      70       55       45       55
# 52  47   Parasect       Bug     Grass  60      95       80       60       80
# 53  48    Venonat       Bug    Poison  60      55       50       40       55
# 54  49   Venomoth       Bug    Poison  70      65       60       90       75
# 55  50    Diglett    Ground       NaN  10      55       25       35       45
# 56  51    Dugtrio    Ground       NaN  35      80       50       50       70
# 57  52     Meowth    Normal       NaN  40      45       35       40       40
# 58  53    Persian    Normal       NaN  65      70       60       65       65
# 59  54    Psyduck     Water       NaN  50      52       48       65       50
# 60  55    Golduck     Water       NaN  80      82       78       95       80
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name'][10:51]
# Out:
# 10                  Wartortle
# 11                  Blastoise
# 12    BlastoiseMega Blastoise
# 13                   Caterpie
# 14                    Metapod
# 15                 Butterfree
# 16                     Weedle
# 17                     Kakuna
# 18                   Beedrill
# 19      BeedrillMega Beedrill
# 20                     Pidgey
# 21                  Pidgeotto
# 22                    Pidgeot
# 23        PidgeotMega Pidgeot
# 24                    Rattata
# 25                   Raticate
# 26                    Spearow
# 27                     Fearow
# 28                      Ekans
# 29                      Arbok
# 30                    Pikachu
# 31                     Raichu
# 32                  Sandshrew
# 33                  Sandslash
# 34           Nidoran (Female)
# 35                   Nidorina
# 36                  Nidoqueen
# 37             Nidoran (Male)
# 38                   Nidorino
# 39                   Nidoking
# 40                   Clefairy
# ...

# %%
df[['Name','Defense','Legendary']][10:51]
# Out:
#                        Name  Defense  Legendary
# 10                Wartortle       80      False
# 11                Blastoise      100      False
# 12  BlastoiseMega Blastoise      120      False
# 13                 Caterpie       35      False
# 14                  Metapod       55      False
# 15               Butterfree       50      False
# 16                   Weedle       30      False
# 17                   Kakuna       50      False
# 18                 Beedrill       40      False
# 19    BeedrillMega Beedrill       40      False
# 20                   Pidgey       40      False
# 21                Pidgeotto       55      False
# 22                  Pidgeot       75      False
# 23      PidgeotMega Pidgeot       80      False
# 24                  Rattata       35      False
# 25                 Raticate       60      False
# 26                  Spearow       30      False
# 27                   Fearow       65      False
# 28                    Ekans       44      False
# ...

# %%
df['Speed'].max()
df['Speed'].min()
df['Speed'].mean()
df['Speed'].describe() #gives a quick statiscs report like mean, std.deviation,min,max etc on the selected parameter
# Out:
# count    800.000000
# mean      68.277500
# std       29.060474
# min        5.000000
# 25%       45.000000
# 50%       65.000000
# 75%       90.000000
# max      180.000000
# Name: Speed, dtype: float64

# %%
df[df.Legendary == True]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df.Speed == df.Speed.max()] #Give me the row where df.speed is maximum
#To print only the name of the pokemon which has maximum speed
df['Name'][df.Speed == df['Speed'].max()]
#To print only the name of the pokemon which has minimum speed
df[['Name','Type 1']][df.Speed == df['Speed'].min()]
# Out:
#          Name  Type 1
# 230   Shuckle     Bug
# 495  Munchlax  Normal

# %%
# To set one of the existing columns as Index
df.set_index('Type 1',inplace=True) #inPlace=True modifies the existing csv file
df
# Out:
#            #  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Grass      1  45      49       49       65       65     45           1
# Grass      2  60      62       63       80       80     60           1
# Grass      3  80      82       83      100      100     80           1
# Grass      3  80     100      123      122      120     80           1
# Fire       4  39      52       43       60       50     65           1
# ...      ...  ..     ...      ...      ...      ...    ...         ...
# Rock     719  50     100      150      100      150     50           6
# Rock     719  50     160      110      160      110    110           6
# Psychic  720  80     110       60      150      130     70           6
# Psychic  720  80     160       60      170      130     80           6
# Fire     721  80     110      120      130       90     70           6
#
#          Legendary
# Type 1
# Grass        False
# Grass        False
# Grass        False
# ...

# %%
df.loc['Rock']
# Out:
#           #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Rock     74   40      80      100       30       30     20           1
# Rock     75   55      95      115       45       45     35           1
# Rock     76   80     120      130       55       65     45           1
# Rock     95   35      45      160       30       45     70           1
# Rock    138   35      40      100       90       55     35           1
# Rock    139   70      60      125      115       70     55           1
# Rock    140   30      80       90       55       45     55           1
# Rock    141   60     115      105       65       70     80           1
# Rock    142   80     105       65       60       75    130           1
# Rock    142   80     135       85       70       95    150           1
# Rock    185   70     100      115       30       65     30           2
# Rock    246   50      64       50       45       50     41           2
# ...
