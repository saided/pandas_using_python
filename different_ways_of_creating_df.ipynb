# %%
import pandas as pd

# %%
#Reading from an Excel sheet
df = pd.read_excel("C:\\Users\\tirumaleswarasai.t\\Desktop\\Vaibhav\\JC_MAIN_EAST.xlsx","Sheet1")
df
# Out:
#      Sr. No.           Site Name / DVR Name        DVR Model    IP Address  \
# 0        NaN         AC_JC_PAAT_01_Pasighat  DS-7208HFI-SH/A  10.84.227.25
# 1        NaN    AC_JC_ITNR_01_Chandan Nagar  DS-7208HFI-SH/A  10.84.192.25
# 2        NaN      AS_GUW_JO_DC_Amin_JI14_D1     DS-7608NI-E2   10.124.1.45
# 3        NaN  AS_JC_NKMP_01_North Lakhimpur  DS-7208HFI-SH/A  10.84.211.25
# 4        NaN          AS_JC_SLCR_01_Silchar  DS-7208HFI-SH/A  10.84.208.25
# ..       ...                            ...              ...           ...
# 190      NaN        WB_JC_KLAG_01_KOLHAGHAT  DS-7208HFI-SH/A   10.84.62.25
# 191      NaN          WB_JC_KLKT_08_Sealdah  DS-7208HFI-SH/A    10.84.7.25
# 192      NaN   WB_JC_KLKT_09_ Agrawal House  DS-7208HFI-SH/A    10.84.8.25
# 193      NaN      WB_JC_KLKT_10_Dargah Road  DS-7208HFI-SH/A    10.84.9.25
# 194      NaN                     JIO Center  DS-7208HFI-SH/A  10.85.160.25
#
#     Username   Password  No. of Channels  \
# ...

# %%
#third way to create a DF through a python dictionary
#here keys are the columns and values are rows
weather_data = {
'day': ['1/1/2017', '1/2/2017', '1/3/2017'],
'temperature': [32, 35, 28],
'windspeed': [6,7,2],
'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# way 4 (python tuple list)
weather_data = [
('1/1/2017', 32, 6, 'Rain'),
('1/2/2017', 35, 7, 'Sunny'),
('1/3/2017', 28, 2, 'Snow')
]
df = pd.DataFrame(weather_data,columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# way 5 (python dictionary list)
weather_data = [
{'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
{'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
{'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'}
]
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
